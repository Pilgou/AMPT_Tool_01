# %% [markdown]
# # Extract table from PDF ( if it's digital pdf file )

# %% [markdown]
# ## <span style="color:red">Camelot n'arrive pas à extrire toutes les lignes</span>

# %%
import camelot
import pandas as pd

# Lecture avec Camelot
tables = camelot.read_pdf("C:/Users/Mamie/Documents/Python/DCS_Devices_tools/AMPT_Tool_01/AMPTconfig/Ampt Gen3CU.pdf", pages="all", flavor="stream")

# Fusionner toutes les tables
dfs = [t.df for t in tables]
df = pd.concat(dfs, ignore_index=True)

# Nettoyer les retours à la ligne
df = df.replace(r"\n", " ", regex=True)

# Supprimer les lignes d'en-tête "Start Offset Size ..."
df = df[~df[0].str.contains("Start", na=False)]
df = df.dropna(how="all")

# Renommer les colonnes correctement
df.columns = ["Start/Offset", "Size", "Name", "Type", "R/W", "Description"]

# Réinitialiser l’index
df = df.reset_index(drop=True)

# Affichage
print("Aperçu du tableau extrait :")
(df.head(20))
# Out:
# Aperçu du tableau extrait :
#    Start/Offset  Size            Name    Type  R/W  \
# 0             5    16    Manufacturer  string    R
# 1
# 2            21    16           Model  string    R
# 3            37     8        Reserved       -    -
# 4            45     8         Version  string    R
# 5            53    16   Serial Number  string    R
# 6            69     1  Device Address   int16  R/W
# 7            71     1              ID  uint16    R
# 8            72     1               L  uint16    R
# 9            73     1          DCA_SF   int16    R
# 10           74     1          DCV_SF   int16    R
# 11           75     1        Reserved       -    -
# 12           76     1        DCkWh_SF   int16    R
# 13           77     1        Reserved       -    -
# 14           78     1               N  uint16    R
# 15           79     6        Reserved       -    -
# 16
# 17       Offset  Size            Name    Type  R/W
# 18           95     2          In2DCV  uint32    R
# 19           97     2            DCWh  uint32    R
#
#                                           Description
# 0      A well-known value registered with SunSpec for
# 1                                    compliance: Ampt
# 2      Manufacturer specific value Communication Unit
# 3
# 4                                    Software Version
# 5                         Manufacturer specific value
# 6                                    Modbus Device ID
# 7                      Ampt SunSpec Vendor Code 64050
# 8   Variable number of 16-bit registers to follow:...
# 9                                Current scale factor
# 10                               Voltage scale factor
# 11
# 12                                Energy Scale Factor
# 13
# 14                                  Number of strings
# 15
# 16                                        Ampt Gen3CU
# 17                                        Description
# 18                       String input 2 voltage in mV
# 19        Daily integrated string output energy in Wh

# %%
# Ajouter les 3 premières lignes manuellement si manquantes
missing_rows = [
    ["1", "2", "SID", "uint32", "R", "A well-known value 0x53756e53, uniquely identifies this as a SunSpec Modbus Map"],
    ["3", "1", "ID", "uint16", "R", "A well-known value 1, uniquely identifies this as a SunSpec Common Model"],
    ["4", "1", "L", "uint16", "R", "Well-known # of 16-bit registers to follow: 66"]
]
if not df.iloc[0].astype(str).str.contains("SID").any():
    print("⚠️ Ligne SID absente → ajout manuel des 3 premières lignes")
    for row in reversed(missing_rows):
        df.loc[-1] = row  # insérer avant
        df.index = df.index + 1
    df = df.sort_index().reset_index(drop=True)
else:
    print("✅ La ligne SID est déjà présente")
# Out:
# ⚠️ Ligne SID absente → ajout manuel des 3 premières lignes

# %%
# Affichage
print("Aperçu du tableau extrait :")
df
# Out:
# Aperçu du tableau extrait :
#    Start/Offset  Size            Name    Type  R/W  \
# 0             1     2             SID  uint32    R
# 1             3     1              ID  uint16    R
# 2             4     1               L  uint16    R
# 3             5    16    Manufacturer  string    R
# 4
# 5            21    16           Model  string    R
# 6            37     8        Reserved       -    -
# 7            45     8         Version  string    R
# 8            53    16   Serial Number  string    R
# 9            69     1  Device Address   int16  R/W
# 10           71     1              ID  uint16    R
# 11           72     1               L  uint16    R
# 12           73     1          DCA_SF   int16    R
# 13           74     1          DCV_SF   int16    R
# 14           75     1        Reserved       -    -
# 15           76     1        DCkWh_SF   int16    R
# 16           77     1        Reserved       -    -
# 17           78     1               N  uint16    R
# 18           79     6        Reserved       -    -
# 19
# 20       Offset  Size            Name    Type  R/W
# 21           95     2          In2DCV  uint32    R
# 22           97     2            DCWh  uint32    R
# 23           99     1          In1DCA   int16    R
# 24          100     1          In2DCA   int16    R
# 25
# 26       Offset  Size            Name    Type  R/W
# 27          141     2          In1DCV  uint32    R
# 28          143     2          In2DCV  uint32    R
# 29          145     2            DCWh  uint32    R
# 30          147     1          In1DCA   int16    R
# 31          148     1          In2DCA   int16    R
#
#                                           Description
# 0   A well-known value 0x53756e53, uniquely identi...
# 1   A well-known value 1, uniquely identifies this...
# 2      Well-known # of 16-bit registers to follow: 66
# 3      A well-known value registered with SunSpec for
# 4                                    compliance: Ampt
# 5      Manufacturer specific value Communication Unit
# 6
# 7                                    Software Version
# 8                         Manufacturer specific value
# 9                                    Modbus Device ID
# 10                     Ampt SunSpec Vendor Code 64050
# 11  Variable number of 16-bit registers to follow:...
# 12                               Current scale factor
# 13                               Voltage scale factor
# 14
# 15                                Energy Scale Factor
# 16
# 17                                  Number of strings
# 18
# 19                                        Ampt Gen3CU
# 20                                        Description
# 21                       String input 2 voltage in mV
# 22        Daily integrated string output energy in Wh
# 23                       String input 1 current in mA
# 24                       String input 2 current in mA
# 25                                        Ampt Gen3CU
# 26                                        Description
# 27                       String input 1 voltage in mV
# 28                       String input 2 voltage in mV
# 29        Daily integrated string output energy in Wh
# 30                       String input 1 current in mA
# 31                       String input 2 current in mA

# %%
# Sauvegarde
df.to_csv("Ampt_Modbus_Map.csv", index=False, encoding="utf-8")
df.to_excel("Ampt_Modbus_Map.xlsx", index=False)
